# %% [markdown]
# # Exploratory Data Analysis
# evaluate the data of _employee in shift_ data with the help of Pandas lib.
#  * period of time: 20200210-20200216
#
# In the following cells we add column names and tell pandas the datatypes we now, mostly date/time types. If we don't pandas will make objects and the dataframe gets too big.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import time

# %%
set_size = 5000

# %% [markdown]
# for future use set the following options, otherwise snippets will only show so much as a default

# %%
pd.set_option('display.max_rows', 90)
pd.set_option('display.max_columns', 90)

# %%
# the headers or column names are not set, luckilly they are available
column_names = ["repository_timestamp",
                "op",
                "dms_timestamp",
                "id",
                "shift_id",
                "start_date_time",
                "end_date_time",
                "realized_start_date_time",
                "realized_end_date_time",
                "comm_to_employee_date_time",
                "comm_to_customer_date_time",
                "is_realiz_ok_by_customer",
                "decl_to_erp_system_date_time",
                "decl_to_erp_system_tag",
                "accept_by_employee_date_time",
                "accept_by_customer_date_time",
                "qual_fast_filter_id",
                "current_qual_percentage",
                "qual_percentage_increment",
                "realized_export_date_time",
                "planned_export_date_time",
                "last_change_date_of_planning",
                "pool_id",
                "customer_in_pool_id",
                "creation_date_time",
                "creation_with_type_id",
                "last_change_with_type_id",
                "deleted_date_time",
                "deleted_with_type_id",
                "comm_to_employee_with_type_id",
                "accept_by_emp_with_type_id",
                "comm_to_customer_with_type_id",
                "planned_export_with_type_id",
                "realized_date_time",
                "realized_with_type_id",
                "accept_by_cust_with_type_id",
                "decl_to_erp_with_type_id",
                "realized_export_with_type_id",
                "employee_id",
                "pool_employee_id",
                "is_first_time_by_customer",
                "event_id",
                "declared_start_date_time",
                "declared_end_date_time",
                "declared_event_id",
                "is_pauses_realized",
                "is_cost_categories_realized",
                "realized_event_id",
                "is_administrative_checked",
                "clocked_start_date_time",
                "clocked_end_date_time",
                "is_realization_doubtful",
                "is_to_evaluate_for_clock",
                "realized_by_employee_date_time",
                "confirmed_date_time",
                "confirmed_with_type_id",
                "viewable_for_emp_date_time",
                "viewable_for_emp_with_type_id",
                "called_up_date_time",
                "called_up_with_type_id",
                "reject_by_emp_date_time",
                "reject_by_emp_with_type_id",
                "reason_edit_emp_shift_type_id",
                "reason_edit_emp_shift_text",
                "changed_planned_hours_dt",
                "changed_event_date_time",
                "reason_deviant_realiz_type_id",
                "deviant_realization_start_dt",
                "deviant_realization_end_dt",
                "reason_deviant_realiz_text",
                "un_reject_by_planner_date_time",
                "current_call_up_id",
                "deviant_realization_event_id",
                "subst_group_id",
                "subst_date_time",
                "subst_with_type_id",
                "subst_prev_emp_in_shift_id",
                "subst_next_emp_in_shift_id",
                "is_on_call_employee",
                "placement_number",
                "is_on_call_source_type_id",
                "decl_examined_date_time",
                "batchid",
                "batch_ts"]
# df.columns = column_names

# %%
date_columns = ["repository_timestamp",
                "dms_timestamp",
                "start_date_time",
                "end_date_time",
                "realized_start_date_time",
                "realized_end_date_time",
                "comm_to_employee_date_time",
                "comm_to_customer_date_time",
                "decl_to_erp_system_date_time",
                "accept_by_employee_date_time",
                "accept_by_customer_date_time",
                "realized_export_date_time",
                "planned_export_date_time",
                "last_change_date_of_planning",
                "creation_date_time",
                "deleted_date_time",
                "realized_date_time",
                "declared_start_date_time",
                "declared_end_date_time",
                "realized_event_id",
                "clocked_start_date_time",
                "clocked_end_date_time",
                "realized_by_employee_date_time",
                "confirmed_date_time",
                "viewable_for_emp_date_time",
                "called_up_date_time",
                "reject_by_emp_date_time",
                "changed_event_date_time",
                "deviant_realization_start_dt",
                "deviant_realization_end_dt",
                "un_reject_by_planner_date_time",
                "subst_date_time",
                "decl_examined_date_time"]

# %%
other_dtypes = {'is_realiz_ok_by_customer':np.bool_,
                'is_first_time_by_customer':np.bool_,
                'is_pauses_realized':np.bool_,
                'is_cost_categories_realized':np.bool_,
                'is_administrative_checked':np.bool_,
                'is_realization_doubtful':np.bool_,
                'is_to_evaluate_for_clock':np.bool_,
                'is_on_call_employee':np.bool_,
                'is_on_call_source_type_id':np.bool_,
                'batchid':str}

# %% [markdown]
# ## Loading the actual data (of interest) & Quick look
# let's load the data, note that we can limit the number of rows with the attribute `nrows`. This is a more general way of loading things. It turns out we don't want all the columns, for the sake of speed, memory and overview we select a subset and only load that using `usecols`. Note that we do not use

# %%
data_folder = Path("K:/some_data/repo_iplan_employee_in_shift_20200210-20200216")
# read only n-rows of the data, say 15
# nrows=15 set? otherwise you get a lot
df = pd.read_csv(data_folder / "repo_iplan_employee_in_shift_20200210-20200216.csv",
                 names=column_names, nrows=15, parse_dates=date_columns)

# %% [markdown]
# count the number of colums

# %%
print("number of columns : ", len(df.columns))
print("number of rows    : ", len(df.index))
# Out:
# number of columns :  84
# number of rows    :  15

# %% [markdown]
# The file is already large, indicating there are a lot of rows, lets count them, (stick to one column)
#
# _NOTE: THE FOLLOWING CELL TAKES OVER A MINUTE_

# %%
dfl = pd.read_csv(data_folder / "repo_iplan_employee_in_shift_20200210-20200216.csv",
                 names=column_names, usecols=[0], parse_dates=[0])
print("number of columns : ", len(dfl.columns))
print("number of rows    : ", len(dfl.index))

# meanwhile limit the setsize, just in case
if set_size > len(dfl.index): 
    set_size = len(dfl.index)
# Out:
# number of columns :  1
# number of rows    :  248119

# %%
# # high level stats on this data
# # number of pools
# dflpools = dfl.groupby(['pool_id']).nunique()
# print("Number of unique pools   : ", len(dflpools.index))
# del dflpools

# dflshifts = dfl.groupby(['shift_id']).nunique()
# print("Number of unique shifts  : ", len(dflshifts.index))
# del dflshifts

# # number of deleted shifts
# dflshift = dfl.dropna(subset='deleted_date_time')
# print("Number of deleted shifts : ", len(dfl.index) - len(dflshift))

# %% [markdown]
# We now have learned that in two weeks 248119 shifts are planned, that is around 125.000 per week, or almost 21.000 per day. Not that loading this data took a looong time, processing with this data takes a long time, but gives good oversight.

# %% [markdown]
# The amount of data is way to big to view in one go, so lets view a snippet

# %%
df.head(5)
# Out:
#         repository_timestamp op              dms_timestamp         id  \
# 0 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.543285  126361814
# 1 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.724086  125706123
# 2 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.933099  126370048
# 3 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.585765  126362871
# 4 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.883311  126373902
#
#     shift_id     start_date_time       end_date_time realized_start_date_time  \
# 0  131254489 2020-02-12 08:00:00 2020-02-12 17:00:00                      NaT
# 1  131073033 2020-02-13 15:15:00 2020-02-13 18:00:00                      NaT
# 2  131959911 2020-02-14 07:00:00 2020-02-14 15:00:00                      NaT
# 3  131940075 2020-02-10 08:32:00 2020-02-10 15:02:00                      NaT
# 4  131077657 2020-02-10 11:30:00 2020-02-10 14:30:00                      NaT
#
#   realized_end_date_time comm_to_employee_date_time  \
# 0                    NaT                        NaT
# 1                    NaT                        NaT
# 2                    NaT                        NaT
# 3                    NaT                        NaT
# 4                    NaT                        NaT
#
#   comm_to_customer_date_time  is_realiz_ok_by_customer  \
# 0        2020-02-07 10:01:40                         0
# 1                        NaT                         0
# 2                        NaT                         0
# 3                        NaT                         0
# 4        2020-02-06 14:33:52                         0
#
#   decl_to_erp_system_date_time  decl_to_erp_system_tag  \
# 0          2020-02-19 20:25:01                     NaN
# 1                          NaT                     NaN
# 2                          NaT                     NaN
# 3                          NaT                     NaN
# 4                          NaT                     NaN
#
#   accept_by_employee_date_time accept_by_customer_date_time  \
# 0          2020-02-06 10:05:14                          NaT
# 1          2020-02-13 14:09:04                          NaT
# 2                          NaT                          NaT
# 3                          NaT                          NaT
# 4                          NaT                          NaT
#
#    qual_fast_filter_id  current_qual_percentage  qual_percentage_increment  \
# 0                  NaN                      NaN                        NaN
# 1                  NaN                      NaN                        NaN
# 2                  NaN                      NaN                        NaN
# 3                  NaN                      NaN                        NaN
# 4                  NaN                      NaN                        NaN
#
#   realized_export_date_time planned_export_date_time  \
# 0                       NaT                      NaT
# 1                       NaT      2020-02-15 08:00:00
# 2                       NaT                      NaT
# 3                       NaT                      NaT
# 4                       NaT                      NaT
#
#   last_change_date_of_planning  pool_id  customer_in_pool_id  \
# 0                          NaT     4550                12705
# 1          2020-02-13 10:31:29     5314                15206
# 2          2020-02-06 09:52:09    11462                56585
# 3          2020-02-06 07:24:07     8222                50627
# 4          2020-02-06 12:03:16     2550                 6242
#
#    creation_date_time  creation_with_type_id  last_change_with_type_id  \
# 0 2020-02-04 16:43:30                      1                      10.0
# 1 2020-01-16 15:07:43                      1                      10.0
# 2 2020-02-05 09:45:35                      1                       NaN
# 3 2020-02-04 17:30:05                      1                       3.0
# 4 2020-02-05 10:16:27                      1                       NaN
#
#     deleted_date_time  deleted_with_type_id  comm_to_employee_with_type_id  \
# 0                 NaT                   NaN                            NaN
# 1                 NaT                   NaN                            NaN
# 2 2020-02-06 09:52:09                   1.0                            NaN
# 3 2020-02-06 07:24:07                   1.0                            NaN
# 4 2020-02-06 12:03:16                   1.0                            NaN
#
#    accept_by_emp_with_type_id  comm_to_customer_with_type_id  \
# 0                        10.0                            1.0
# 1                        10.0                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            1.0
#
#    planned_export_with_type_id realized_date_time  realized_with_type_id  \
# 0                          NaN                NaT                    NaN
# 1                          1.0                NaT                    NaN
# 2                          NaN                NaT                    NaN
# 3                          NaN                NaT                    NaN
# 4                          NaN                NaT                    NaN
#
#    accept_by_cust_with_type_id  decl_to_erp_with_type_id  \
# 0                          NaN                       8.0
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
#
#    realized_export_with_type_id  employee_id  pool_employee_id  \
# 0                           NaN       823499           1136288
# 1                           NaN       851774           1172843
# 2                           NaN       861425           1185349
# 3                           NaN       883647           1214419
# 4                           NaN       386860            741826
#
#    is_first_time_by_customer  event_id declared_start_date_time  \
# 0                          0       NaN                      NaT
# 1                          0       NaN                      NaT
# 2                          0       NaN                      NaT
# 3                          0     212.0                      NaT
# 4                          0       NaN                      NaT
#
#   declared_end_date_time  declared_event_id  is_pauses_realized  \
# 0                    NaT                NaN                   0
# 1                    NaT                NaN                   0
# 2                    NaT                NaN                   0
# 3                    NaT                NaN                   0
# 4                    NaT                NaN                   0
#
#    is_cost_categories_realized realized_event_id  is_administrative_checked  \
# 0                            0               NaT                          0
# 1                            0               NaT                          0
# 2                            0               NaT                          0
# 3                            0               NaT                          0
# 4                            0               NaT                          0
#
#   clocked_start_date_time clocked_end_date_time  is_realization_doubtful  \
# 0                     NaT                   NaT                        0
# 1                     NaT                   NaT                        0
# 2                     NaT                   NaT                        0
# 3                     NaT                   NaT                        0
# 4                     NaT                   NaT                        0
#
#    is_to_evaluate_for_clock realized_by_employee_date_time  \
# 0                         0                            NaT
# 1                         0                            NaT
# 2                         0                            NaT
# 3                         0                            NaT
# 4                         0                            NaT
#
#   confirmed_date_time  confirmed_with_type_id viewable_for_emp_date_time  \
# 0                 NaT                     NaN                        NaT
# 1                 NaT                     NaN                        NaT
# 2                 NaT                     NaN                        NaT
# 3                 NaT                     NaN                        NaT
# 4                 NaT                     NaN                        NaT
#
#    viewable_for_emp_with_type_id called_up_date_time  called_up_with_type_id  \
# 0                            NaN 2020-02-04 16:44:18                     1.0
# 1                            NaN 2020-02-13 10:31:42                     1.0
# 2                            NaN                 NaT                     NaN
# 3                            NaN 2020-02-04 17:30:07                     1.0
# 4                            NaN 2020-02-05 10:16:30                     1.0
#
#   reject_by_emp_date_time  reject_by_emp_with_type_id  \
# 0                     NaT                         NaN
# 1                     NaT                         NaN
# 2                     NaT                         NaN
# 3                     NaT                         NaN
# 4                     NaT                         NaN
#
#    reason_edit_emp_shift_type_id reason_edit_emp_shift_text  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
#
#      changed_planned_hours_dt changed_event_date_time  \
# 0                         NaN                     NaT
# 1  2020-02-13 10:31:29.000000                     NaT
# 2                         NaN                     NaT
# 3                         NaN     2020-02-04 21:11:34
# 4                         NaN                     NaT
#
#    reason_deviant_realiz_type_id deviant_realization_start_dt  \
# 0                            NaN                          NaT
# 1                            NaN                          NaT
# 2                            NaN                          NaT
# 3                            NaN                          NaT
# 4                            NaN                          NaT
#
#   deviant_realization_end_dt  reason_deviant_realiz_text  \
# 0                        NaT                         NaN
# 1                        NaT                         NaN
# 2                        NaT                         NaN
# 3                        NaT                         NaN
# 4                        NaT                         NaN
#
#   un_reject_by_planner_date_time  current_call_up_id  \
# 0                            NaT           1047474.0
# 1                            NaT           1277662.0
# 2                            NaT                 NaN
# 3                            NaT           1094076.0
# 4                            NaT           1108434.0
#
#    deviant_realization_event_id  subst_group_id subst_date_time  \
# 0                           NaN             302             NaT
# 1                           NaN            5068             NaT
# 2                           NaN           69649             NaT
# 3                           NaN            1310             NaT
# 4                           NaN           37416             NaT
#
#    subst_with_type_id  subst_prev_emp_in_shift_id  subst_next_emp_in_shift_id  \
# 0                 NaN                         NaN                         NaN
# 1                 NaN                         NaN                         NaN
# 2                 NaN                         NaN                         NaN
# 3                 NaN                         NaN                         NaN
# 4                 NaN                         NaN                         NaN
#
#    is_on_call_employee  placement_number  is_on_call_source_type_id  \
# 0                  NaN               NaN                        NaN
# 1                  NaN               NaN                        NaN
# 2                  NaN               NaN                        NaN
# 3                  NaN               NaN                        NaN
# 4                  NaN               NaN                        NaN
#
#   decl_examined_date_time                               batchid  \
# 0     2020-02-19 20:25:01  5638c68a-1d30-4287-8c7e-d013253d7b04
# 1                     NaT  5638c68a-1d30-4287-8c7e-d013253d7b04
# 2                     NaT  5638c68a-1d30-4287-8c7e-d013253d7b04
# 3                     NaT  5638c68a-1d30-4287-8c7e-d013253d7b04
# 4                     NaT  5638c68a-1d30-4287-8c7e-d013253d7b04
#
#                      batch_ts
# 0  2020-08-18 15:08:13.000000
# 1  2020-08-18 15:08:13.000000
# 2  2020-08-18 15:08:13.000000
# 3  2020-08-18 15:08:13.000000
# 4  2020-08-18 15:08:13.000000

# %% [markdown]
# For now we take a subset of column we are interested in, you can always come back later and more if needed. Note that we do limit `nrows` in the end, less rows speeds up the graphical work.

# %%
cols_of_interest=["repository_timestamp",
                "op",
                "dms_timestamp",
                "id",
                "shift_id",
                "start_date_time",
                "end_date_time",
                "realized_start_date_time",
                "realized_end_date_time",
                "employee_id",
                "pool_employee_id",
                 "pool_id",
                 "confirmed_date_time", # level of interest doubtfull
                 "called_up_date_time",
                 "decl_to_erp_system_date_time",
                 "accept_by_employee_date_time",
                 "viewable_for_emp_date_time",
                 "deleted_date_time"]

# %%
# get specific for some calculations
dfwt = pd.read_csv(data_folder / "repo_iplan_employee_in_shift_20200210-20200216.csv", 
                       names=column_names, usecols=cols_of_interest, parse_dates=["repository_timestamp",
                "dms_timestamp",
                "start_date_time",
                "end_date_time",
                "realized_start_date_time",
                "realized_end_date_time",
                "decl_to_erp_system_date_time",
                "accept_by_employee_date_time",
                "viewable_for_emp_date_time",
                "deleted_date_time",
                "called_up_date_time"], nrows=set_size, skip_blank_lines=False)
# obsolete
# dfwt['StartTimeCount'] = pd.to_datetime(dfwt['start_date_time']).dt.strftime('%H:%M:%S')

# %%
dfwt.head(15)
# Out:
#          repository_timestamp op              dms_timestamp         id  \
# 0  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.543285  126361814
# 1  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.724086  125706123
# 2  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.933099  126370048
# 3  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.585765  126362871
# 4  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.883311  126373902
# 5  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.327787  126292562
# 6  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.550083  126364066
# 7  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.536121  126362278
# 8  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.967405  126372619
# 9  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.019093  126363649
# 10 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.820461  126383192
# 11 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.037814  126370086
# 12 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.025958  126373425
# 13 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:49.981463  126580394
# 14 2020-08-18 20:22:52.059095  I 2020-08-18 14:43
# 12                 NaT       783020           1084086                 NaN
# 13                 NaT       477442            684645                 NaN
# 14                 NaT       704148           1006573                 NaN
#
#    viewable_for_emp_date_time called_up_date_time
# 0                         NaT 2020-02-04 16:44:18
# 1                         NaT 2020-02-13 10:31:42
# 2                         NaT                 NaT
# 3                         NaT 2020-02-04 17:30:07
# 4                         NaT 2020-02-05 10:16:30
# 5                         NaT                 NaT
# 6                         NaT 2020-02-05 07:44:24
# 7         2020-02-05 11:22:08 2020-02-16 11:40:50
# 8                         NaT 2020-02-05 15:48:47
# 9         2020-02-04 21:00:07 2020-02-06 10:31:01
# 10                        NaT 2020-02-07 15:49:55
# 11                        NaT 2020-02-07 09:43:28
# 12                        NaT 2020-02-05 12:31:28
# 13                        NaT 2020-02-11 11:55:26
# 14                        NaT 2020-01-21 15:44:54

# %% [markdown]
# ## Shifts, Employees and Pools
# All very connected, but for having an idea how is this organised, what is the scale?
# Count shifts, uniques shifts and say something about the duplication numbers.
# Count Employees.

# %%
# check is all shifts have an idea
print("shifts with no id : ", dfwt['shift_id'].isna().sum())

# group by shift id - how many unique shifts are there
# dfwt["ShiftID_Copy"] = dfwt['shift_id']
# dfwt[dfwt.duplicated(['shift_id'], keep=False)]
dfun = dfwt.groupby(['shift_id']).nunique()
print("unique shifts : ", len(dfun.index))

# you can also check for duplicates, first of set duplicates is set to False, following duplicates are marked True
print("Duplicates:\n", dfwt.duplicated(subset='shift_id', keep='first').value_counts())
# Out:
# shifts with no id :  0
# unique shifts :  3975
# Duplicates:
#  False    3975
# True     1025
# dtype: int64

# %%
# check if all shifts are assigned to an employee
print("number of missing Employee IDs: ", dfwt['employee_id'].isna().sum())

dfun = dfwt.groupby(['employee_id']).nunique()
print("unique employees : ", len(dfun.index))
# Out:
# number of missing Employee IDs:  0
# unique employees :  3902

# %%
# get some info about pools
print("number of missing pool ids: ", dfwt['employee_id'].isna().sum())


dfun = dfwt.groupby(['pool_id']).nunique()
print("unique pools : ", len(dfun.index))
dfun
# Out:
# number of missing pool ids:  0
# unique pools :  322
#          repository_timestamp  op  dms_timestamp   id  shift_id  \
# pool_id
# 24                          1   1             60   60        29
# 29                          1   1              3    3         3
# 30                          1   1              5    5         4
# 32                          1   1              1    1         1
# 42                          1   1            119  119        66
# ...                       ...  ..            ...  ...       ...
# 20705                       1   1              2    2         2
# 20723                       1   1              6    6         6
# 20783                       1   1              3    3         3
# 20843                       1   1              1    1         1
# 20863                       1   1             24   24        21
#
#          start_date_time  end_date_time  realized_start_date_time  \
# pool_id
# 24                    20             19                        17
# 29                     3              3                         0
# 30                     3              3                         0
# 32                     1              1                         0
# 42                    23             30                        20
# ...                  ...            ...                       ...
# 20705                  2              2                         0
# 20723                  6              6                         5
# 20783                  3              3                         0
# 20843                  1              1                         1
# 20863                  8              9                         0
#
#          realized_end_date_time  decl_to_erp_system_date_time  \
# pool_id
# 24                           18                            25
# 29                            0                             0
# 30                            0                             2
# 32                            0                             0
# 42                           16                             6
# ...                         ...                           ...
# 20705                         0                             0
# 20723                         4                             4
# 20783                         0                             2
# 20843                         1                             1
# 20863                         0                            13
#
#          accept_by_employee_date_time  pool_id  deleted_date_time  \
# pool_id
# 24                                 35        1                 19
# 29                                  2        1                  0
# 30                                  2        1                  1
# 32                                  1        1                  0
# 42                                 32        1                 66
# ...                               ...      ...                ...
# 20705                               1        1                  0
# 20723                               5        1                  0
# 20783                               1        1                  1
# 20843                               1        1                  0
# 20863                              12        1                  0
#
#          employee_id  pool_employee_id  confirmed_date_time  \
# pool_id
# 24                39                39                    0
# 29                 1                 1                    0
# 30                 5                 5                    0
# 32                 1                 1                    0
# 42                78                78                    0
# ...              ...               ...                  ...
# 20705              2                 2                    0
# 20723              5                 5                    0
# 20783              2                 2                    0
# 20843              1                 1                    0
# 20863             20                20                    0
#
#          viewable_for_emp_date_time  called_up_date_time
# pool_id
# 24                                1                    4
# 29                                0                    1
# 30                                1                    3
# 32                                1                    1
# 42                                2                    5
# ...                             ...                  ...
# 20705                             0                    1
# 20723                             0                    2
# 20783                             0                    1
# 20843                             1                    1
# 20863                             1                    1
#
# [322 rows x 18 columns]

# %% [markdown]
# lets dive a little more in a pool, let's take pool 24

# %%
# make a df containing only pool 24
dfp24 = dfwt[(dfwt.pool_id) == 24 ]
dfp24.head(15)
# Out:
#           repository_timestamp op              dms_timestamp         id  \
# 18  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.933435  126370228
# 91  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:56.463206  126374681
# 123 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.356982  126371735
# 190 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:56.463290  126374684
# 210 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:50.284271  126371459
# 217 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:59.032297  126372141
# 298 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:56.444534  126371610
# 347 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.045378  126370579
# 397 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.030441  126370255
# 410 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.037970  126370094
# 460 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:56.446872  126372859
# 573 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.933532  126370457
# 732 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.027128  126370194
# 761 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:01.327252  126371896
# 797 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.045823  126370637
#
#       shift_id     start_date_time       end_date_time  \
# 18   130674136 2020-02-12 13:30:00 2020-02-12 22:00:00
# 91   130727194 2020-02-10 07:00:00 2020-02-10 13:30:00
# 123  130727201 2020-02-10 07:00:00 2020-02-10 15:30:00
# 190  130727194 2020-02-10 07:00:00 2020-02-10 13:30:00
# 210  130727202 2020-02-11 07:00:00 2020-02-11 15:30:00
# 217  130727204 2020-02-13 07:00:00 2020-02-13 15:30:00
# 298  130727204 2020-02-13 07:00:00 2020-02-13 15:30:00
# 347  130714479 2020-02-14 07:00:00 2020-02-14 15:30:00
# 397  130674165 2020-02-13 07:00:00 2020-02-13 15:30:00
# 410  130674141 2020-02-10 12:30:00 2020-02-10 21:00:00
# 460  130727240 2020-02-14 17:00:00 2020-02-14 22:00:00
# 573  131939170 2020-02-14 15:30:00 2020-02-14 19:00:00
# 732  130674138 2020-02-14 13:30:00 2020-02-14 22:00:00
# 761  130727202 2020-02-11 07:00:00 2020-02-11 15:30:00
# 797  130714503 2020-02-10 13:30:00 2020-02-10 22:00:00
#
#     realized_start_date_time realized_end_date_time  \
# 18       2020-02-12 13:30:00    2020-02-12 22:00:00
# 91       2020-02-10 07:00:00    2020-02-10 13:30:00
# 123                      NaT                    NaT
# 190      2020-02-10 07:00:00    2020-02-10 13:30:00
# 210      2020-02-11 07:00:00    2020-02-11 15:30:00
# 217      2020-02-13 07:00:00    2020-02-13 15:30:00
# 298                      NaT                    NaT
# 347                      NaT                    NaT
# 397      2020-02-13 07:00:00    2020-02-13 15:30:00
# 410      2020-02-10 12:30:00    2020-02-10 21:00:00
# 460                      NaT                    NaT
# 573                      NaT                    NaT
# 732      2020-02-14 13:30:00    2020-02-14 22:00:00
# 761      2020-02-11 07:00:00    2020-02-11 13:30:00
# 797                      NaT                    NaT
#
#     decl_to_erp_system_date_time accept_by_employee_date_time  pool_id  \
# 18           2020-02-13 06:32:17          2020-02-06 12:21:17       24
# 91           2020-02-10 19:16:19          2020-02-05 19:34:00       24
# 123                          NaT                          NaT       24
# 190          2020-02-10 19:16:19          2020-02-06 01:46:49       24
# 210          2020-02-11 18:58:26          2020-02-05 17:44:47       24
# 217          2020-02-13 17:39:02          2020-02-05 17:15:03       24
# 298                          NaT                          NaT       24
# 347                          NaT          2020-02-05 17:33:26       24
# 397          2020-02-13 17:39:12          2020-02-05 16:58:15       24
# 410          2020-02-11 06:32:49          2020-02-05 19:03:59       24
# 460                          NaT                          NaT       24
# 573                          NaT          2020-02-06 12:45:22       24
# 732          2020-02-17 06:29:42          2020-02-05 17:13:34       24
# 761          2020-02-11 18:58:26          2020-02-05 21:01:27       24
# 797                          NaT                          NaT       24
#
#       deleted_date_time  employee_id  pool_employee_id confirmed_date_time  \
# 18                  NaT       794214           1103483                 NaN
# 91                  NaT       869525           1195526                 NaN
# 123 2020-02-05 10:22:07       874746           1202680                 NaN
# 190                 NaT       858992           1182107                 NaN
# 210                 NaT       841789           1162163                 NaN
# 217                 NaT       516881            733766                 NaN
# 298                 NaT       683808           1104904                 NaN
# 347                 NaT       850892           1171739                 NaN
# 397                 NaT       704061            979415                 NaN
# 410                 NaT       793002           1097099                 NaN
# 460 2020-02-05 10:10:49       527025            746166                 NaN
# 573 2020-02-13 15:01:03       527731            747126                 NaN
# 732                 NaT       528963            748701                 NaN
# 761                 NaT        83136            101340                 NaN
# 797 2020-02-05 15:50:59       797771           1103312                 NaN
#
#     viewable_for_emp_date_time called_up_date_time
# 18                         NaT 2020-02-05 16:56:00
# 91                         NaT 2020-02-05 16:56:00
# 123                        NaT                 NaT
# 190                        NaT 2020-02-05 16:56:00
# 210                        NaT 2020-02-05 16:56:00
# 217                        NaT 2020-02-05 16:56:00
# 298                        NaT 2020-02-10 16:54:59
# 347                        NaT 2020-02-10 16:54:59
# 397                        NaT 2020-02-05 16:56:00
# 410                        NaT 2020-02-05 16:56:00
# 460                        NaT                 NaT
# 573                        NaT 2020-02-05 16:56:00
# 732                        NaT 2020-02-05 16:56:00
# 761                        NaT 2020-02-05 16:56:00
# 797                        NaT                 NaT

# %%
# lets take a pool that has around 14 - 21 shifts: 2 a 3 per day
dfun['dms_timestamp'].sort_values()

dfun2 = dfun[dfun['dms_timestamp'].between(14, 21)]
dfun2.head(5)
# Out:
#          repository_timestamp  op  dms_timestamp  id  shift_id  \
# pool_id
# 229                         1   1             17  17        15
# 347                         1   1             19  19         9
# 351                         1   1             21  21        20
# 2466                        1   1             20  20        15
# 3746                        1   1             14  14         8
#
#          start_date_time  end_date_time  realized_start_date_time  \
# pool_id
# 229                    9              9                         6
# 347                    9              9                         6
# 351                   17             16                        14
# 2466                  13             13                         8
# 3746                   8              7                         5
#
#          realized_end_date_time  decl_to_erp_system_date_time  \
# pool_id
# 229                           7                             8
# 347                           7                            13
# 351                          14                             2
# 2466                          8                             7
# 3746                          5                             8
#
#          accept_by_employee_date_time  pool_id  deleted_date_time  \
# pool_id
# 229                                 8        1                  4
# 347                                13        1                  6
# 351                                 1        1                  4
# 2466                               11        1                  3
# 3746                               13        1                  1
#
#          employee_id  pool_employee_id  confirmed_date_time  \
# pool_id
# 229               15                15                    0
# 347               16                16                    0
# 351               20                20                    0
# 2466              17                17                    0
# 3746              13                13                    0
#
#          viewable_for_emp_date_time  called_up_date_time
# pool_id
# 229                              14                    7
# 347                               0                   12
# 351                               0                    1
# 2466                              9                    2
# 3746                              1                    7

# %%
# make a df containing only pool 229
dfp229 = dfwt[(dfwt.pool_id) == 229 ]
print(len(dfp229.index)) # nr shifts in this pool
# Out:
# 17

# %% [markdown]
# The above looks interesting. What means no `realized_start_date_time`? In the following cells we will zoom in on pool 229 (because it is not too big neither too small) and investigate the entire 84 columns:

# %%
dfp229 = dfp229.sort_values('start_date_time')

# %%
dfp229all = pd.read_csv(data_folder / "repo_iplan_employee_in_shift_20200210-20200216.csv",
                 names=column_names, nrows=5000, parse_dates=date_columns)
# only load the indexes containing 229 info
pool229ids = np.transpose(list(dfp229.index))
dfp229all = dfp229all.iloc[pool229ids,:]

# %%
sel229 = ["shift_id",
          "start_date_time", 
          "end_date_time","realized_start_date_time",
          "realized_end_date_time",
          "decl_to_erp_system_date_time",
          "accept_by_employee_date_time",
          "employee_id",
          "viewable_for_emp_date_time",
          "called_up_date_time",
          "deleted_date_time"]
dfp229sel = dfp229all[sel229]
# if you want to inspect a certain shift
# dfp229sel[(dfp229sel.shift_id) == 130309679 ]
# or just take some rows
len229 = len(dfp229sel.index)
dfp229sel.head(len229)
# Out:
#        shift_id     start_date_time       end_date_time  \
# 3064  130026238 2020-02-09 08:30:00 2020-02-09 18:00:00
# 2602  130026238 2020-02-09 08:30:00 2020-02-09 18:00:00
# 3185  130024026 2020-02-09 08:30:00 2020-02-09 18:00:00
# 3823  130309678 2020-02-10 15:10:00 2020-02-10 22:55:00
# 3943  130309735 2020-02-11 07:10:00 2020-02-11 15:10:00
# 2999  130290457 2020-02-11 07:10:00 2020-02-11 15:10:00
# 3615  130309679 2020-02-11 15:10:00 2020-02-11 22:55:00
# 4063  130309736 2020-02-12 07:10:00 2020-02-12 15:10:00
# 4821  130290458 2020-02-12 07:10:00 2020-02-12 15:10:00
# 4902  130309680 2020-02-12 15:10:00 2020-02-12 22:55:00
# 3030  130309681 2020-02-13 15:10:00 2020-02-13 22:55:00
# 3673  130264547 2020-02-15 08:30:00 2020-02-15 18:00:00
2020-08-18 20:22:52.059095  I 2020-08-18 14:43:56.473142  126370721
# 2999 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:49.727877  124870376
# 3615 2020-08-18 20:22:52.059095  I 2020-08-18 14:58:19.412232  124870586
# 4063 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:59.004458  126368624
#
#        shift_id     start_date_time       end_date_time  \
# 3943  130309735 2020-02-11 07:10:00 2020-02-11 15:10:00
# 2999  130290457 2020-02-11 07:10:00 2020-02-11 15:10:00
# 3615  130309679 2020-02-11 15:10:00 2020-02-11 22:55:00
# 4063  130309736 2020-02-12 07:10:00 2020-02-12 15:10:00
#
#      realized_start_date_time realized_end_date_time  \
# 3943      2020-02-11 07:10:00    2020-02-11 15:10:00
# 2999      2020-02-11 07:10:00    2020-02-11 15:10:00
# 3615                      NaT                    NaT
# 4063                      NaT                    NaT
#
#      comm_to_employee_date_time comm_to_customer_date_time  \
# 3943                        NaT                        NaT
# 2999                        NaT                        NaT
# 3615                        NaT                        NaT
# 4063                        NaT                        NaT
#
#       is_realiz_ok_by_customer decl_to_erp_system_date_time  \
# 3943                         1          2020-02-11 15:12:51
# 2999                         1          2020-02-11 15:12:52
# 3615                         0                          NaT
# 4063                         0                          NaT
#
#       decl_to_erp_system_tag accept_by_employee_date_time  \
# 3943                     NaN                          NaT
# 2999                     NaN          2020-02-06 13:30:16
# 3615                     NaN                          NaT
# 4063                     NaN                          NaT
#
#      accept_by_customer_date_time  qual_fast_filter_id  \
# 3943          2020-02-11 15:12:51                  NaN
# 2999          2020-02-11 15:12:51                  NaN
# 3615                          NaT                  NaN
# 4063                          NaT                  NaN
#
#       current_qual_percentage  qual_percentage_increment  \
# 3943                      NaN                        NaN
# 2999                      NaN                        NaN
# 3615                      NaN                        NaN
# 4063                      NaN                        NaN
#
#      realized_export_date_time planned_export_date_time  \
# 3943                       NaT                      NaT
# 2999                       NaT                      NaT
# 3615                       NaT                      NaT
# 4063                       NaT                      NaT
#
#      last_change_date_of_planning  pool_id  customer_in_pool_id  \
# 3943          2020-02-10 12:35:37      229                  310
# 2999                          NaT      229                  310
# 3615                          NaT      229                  310
# 4063          2020-02-11 11:28:35      229                  310
#
#       creation_date_time  creation_with_type_id  last_change_with_type_id  \
# 3943 2020-02-05 09:54:19                      1                       1.0
# 2999 2019-12-23 00:53:20                      4                      10.0
# 3615 2019-12-23 00:53:33                      4                       NaN
# 4063 2020-02-05 09:29:12                      4                       1.0
#
#      deleted_date_time  deleted_with_type_id  comm_to_employee_with_type_id  \
# 3943               NaT                   NaN                            NaN
# 2999               NaT                   NaN                            NaN
# 3615               NaT                   NaN                            NaN
# 4063               NaT                   NaN                            NaN
#
#       accept_by_emp_with_type_id  comm_to_customer_with_type_id  \
# 3943                         NaN                            NaN
# 2999                        10.0                            NaN
# 3615                         NaN                            NaN
# 4063                         NaN                            NaN
#
#       planned_export_with_type_id  realized_date_time  realized_with_type_id  \
# 3943                          NaN 2020-02-11 15:10:00                    9.0
# 2999                          NaN 2020-02-11 15:10:00                    9.0
# 3615                          NaN                 NaT                    NaN
# 4063                          NaN                 NaT                    NaN
#
#       accept_by_cust_with_type_id  decl_to_erp_with_type_id  \
# 3943                          2.0                       2.0
# 2999                          2.0                       2.0
# 3615                          NaN                       NaN
# 4063                          NaN                       NaN
#
#       realized_export_with_type_id  employee_id  pool_employee_id  \
# 3943                           NaN       891733           1224975
# 2999                           NaN       284132            387268
# 3615                           NaN       666043            929961
# 4063                           NaN       891722           1224946
#
#       is_first_time_by_customer  event_id declared_start_date_time  \
# 3943                          0       NaN      2020-02-11 07:10:00
# 2999                          0       NaN      2020-02-11 07:10:00
# 3615                          0       7.0                      NaT
# 4063                          0      10.0                      NaT
#
#      declared_end_date_time  declared_event_id  is_pauses_realized  \
# 3943    2020-02-11 15:10:00                NaN                   1
# 2999    2020-02-11 15:10:00                NaN                   1
# 3615                    NaT                NaN                   0
# 4063                    NaT                NaN                   0
#
#       is_cost_categories_realized realized_event_id  \
# 3943                            1               NaN
# 2999                            1               NaN
# 3615                            0               NaN
# 4063                            0               113
#
#       is_administrative_checked clocked_start_date_time clocked_end_date_time  \
# 3943                          0     2020-02-11 07:05:00   2020-02-11 15:10:00
# 2999                          0     2020-02-11 07:00:00   2020-02-11 15:10:00
# 3615                          0                     NaT                   NaT
# 4063                          0                     NaT                   NaT
#
#       is_realization_doubtful  is_to_evaluate_for_clock  \
# 3943                        0                         0
# 2999                        0                         0
# 3615                        0                         0
# 4063                        0                         0
#
#      realized_by_employee_date_time confirmed_date_time  \
# 3943                            NaT                 NaT
# 2999                            NaT                 NaT
# 3615                            NaT                 NaT
# 4063                            NaT                 NaT
#
#       confirmed_with_type_id viewable_for_emp_date_time  \
# 3943                     NaN                        NaT
# 2999                     NaN        2019-12-23 00:53:20
# 3615                     NaN        2019-12-23 00:53:33
# 4063                     NaN        2020-02-05 09:29:12
#
#       viewable_for_emp_with_type_id called_up_date_time  \
# 3943                            NaN 2020-02-10 12:36:31
# 2999                            4.0 2020-02-06 13:28:16
# 3615                            4.0                 NaT
# 4063                            4.0 2020-02-11 11:29:04
#
#       called_up_with_type_id reject_by_emp_date_time  \
# 3943                     1.0                     NaT
# 2999                     1.0                     NaT
# 3615                     NaN                     NaT
# 4063                     1.0                     NaT
#
#       reject_by_emp_with_type_id  reason_edit_emp_shift_type_id  \
# 3943                         NaN                            NaN
# 2999                         NaN                            NaN
# 3615                         NaN                            NaN
# 4063                         NaN                            NaN
#
#      reason_edit_emp_shift_text changed_planned_hours_dt  \
# 3943                        NaN                      NaN
# 2999                        NaN                      NaN
# 3615                        NaN                      NaN
# 4063                        NaN                      NaN
#
#      changed_event_date_time  reason_deviant_realiz_type_id  \
# 3943     2020-02-10 12:35:37                            NaN
# 2999                     NaT                            NaN
# 3615     2020-01-20 12:49:53                            NaN
# 4063     2020-02-11 11:28:35                            NaN
#
#      deviant_realization_start_dt deviant_realization_end_dt  \
# 3943                          NaT                        NaT
# 2999                          NaT                        NaT
# 3615                          NaT                        NaT
# 4063                          NaT                        NaT
#
#      reason_deviant_realiz_text un_reject_by_planner_date_time  \
# 3943                        NaN                            NaT
# 2999                        NaN                            NaT
# 3615                        NaN                            NaT
# 4063                        NaN                            NaT
#
#       current_call_up_id  deviant_realization_event_id  subst_group_id  \
# 3943           1115199.0                           NaN          311712
# 2999           1114828.0                           NaN        28032972
# 3615                 NaN                           NaN        21072787
# 4063           1115189.0                           NaN          381298
#
#      subst_date_time  subst_with_type_id  subst_prev_emp_in_shift_id  \
# 3943             NaT                 NaN                         NaN
# 2999             NaT                 NaN                         NaN
# 3615             NaT                 NaN                         NaN
# 4063             NaT                 NaN                         NaN
#
#       subst_next_emp_in_shift_id  is_on_call_employee  placement_number  \
# 3943                         NaN                  NaN               NaN
# 2999                         NaN                  NaN               NaN
# 3615                         NaN                  NaN               NaN
# 4063                         NaN                  NaN               NaN
#
#       is_on_call_source_type_id decl_examined_date_time  \
# 3943                        NaN     2020-02-11 15:12:51
# 2999                        NaN     2020-02-11 15:12:52
# 3615                        NaN                     NaT
# 4063                        NaN                     NaT
#
#                                    batchid                    batch_ts
# 3943  5638c68a-1d30-4287-8c7e-d013253d7b04  2020-08-18 15:08:13.000000
# 2999  5638c68a-1d30-4287-8c7e-d013253d7b04  2020-08-18 15:08:13.000000
# 3615  836d0932-4112-4da5-8bfd-41524bbe3955  2020-08-18 15:08:13.000000
# 4063  5638c68a-1d30-4287-8c7e-d013253d7b04  2020-08-18 15:08:13.000000

# %% [markdown]
# ## Pool evaluation
# I worked out this in a more nicely formated table (in this google doc [https://docs.google.com/spreadsheets/d/1R7CrE_quP0pSiJH8gbbNLhdeK7soBsYwxZ0-lYY1u-c/edit#gid=1111727723])
#
# ### Replanning
# A problem of the planners might be that they have to replan a lot. It might be interesting if there are features that could point out wether a shift 'will give planning trouble'.
#
# ### Observations
# In this mini example of out of 17 planned shifts, 4 are deleted, 8 are realized. A number of shifts are accepted, but have no realisation. Let's dive in these attributes a bit more:

# %%
dfwt['decl_to_erp_system_date_time'].count()
# Out:
# 1788

# %%
# lets reuse the selection list and apply it to the selection of 5000
for h in sel229:
    sumna = dfwt[h].isna().sum()
    print("Sum of isna in " + h, " : ", sumna)
# Out:
# Sum of isna in shift_id  :  0
# Sum of isna in start_date_time  :  0
# Sum of isna in end_date_time  :  0
# Sum of isna in realized_start_date_time  :  3505
# Sum of isna in realized_end_date_time  :  3510
# Sum of isna in decl_to_erp_system_date_time  :  3212
# Sum of isna in accept_by_employee_date_time  :  2104
# Sum of isna in employee_id  :  0
# Sum of isna in viewable_for_emp_date_time  :  3700
# Sum of isna in called_up_date_time  :  1165
# Sum of isna in deleted_date_time  :  3577

# %% [markdown]
# Note that shift_id and start/end date are never missing (in any of the 5000 cases). Furthermore we note following
#  - not all shifts are realized, (3505), this might relate to:
#    - 5000-3577=1423 shifts have a `deleted_date_time ` i.e. they are deleted
#    - neither calling or accepting did not lead to a realised shift
#  - (as for now) only
#
#  We note we have some statistics on called employees, and also on accepted shifts, but did those end up in realized shifts?

# %%
# check called up shifts
dfrelcal = dfwt.dropna(subset=['called_up_date_time'])
ncalup = len(dfrelcal.index)
nrcalup = dfrelcal['realized_start_date_time'].isna().sum()

# check accepted but not called
dfcalled = dfwt['called_up_date_time'].isna()
# dfnocall = dfwt.isnull(subset=['called_up_date_time'])

dfaccepted = dfwt.dropna(subset=['accept_by_employee_date_time'])
dfnocallaccepted = dfaccepted.isna()
nrnocallaccepted = dfnocallaccepted.called_up_date_time.value_counts()
nrnocallaccepted = nrnocallaccepted[0]


# check called up and accepted
calupaccept = dfrelcal.dropna(subset=['accept_by_employee_date_time'])
nrcalupaccept = calupaccept['realized_start_date_time'].isna().sum

totalshifts = len(dfwt.index)
print(ncalup, " called up shifts, out of which ", nrcalup, " not realised. Total shifts: ", totalshifts)
print(nrcalupaccept, " called and accepted shifts, however ", nrcalupaccept, " not realised")

# check accepted shifts
dfrelacc =dfwt.dropna(subset=['accept_by_employee_date_time'])
# Out:
# 3835  called up shifts, out of which  2384  not realised. Total shifts:  5000
# <bound method Series.sum of 0        True
# 1        True
# 6       False
# 7       False
# 9       False
#         ...
# 4990    False
# 4991    False
# 4997    False
# 4998    False
# 4999    False
# Name: realized_start_date_time, Length: 2895, dtype: bool>  called and accepted shifts, however  <bound method Series.sum of 0        True
# 1        True
# 6       False
# 7       False
# 9       False
#         ...
# 4990    False
# 4991    False
# 4997    False
# 4998    False
# 4999    False
# Name: realized_start_date_time, Length: 2895, dtype: bool>  not realised

# %%
# how many shift are there?
nrShifts = len(dfwt.index)
print("Total number of shifts in examined set: ", nrShifts)

# how many viewable shifts are there?
nrViewableShifts = dfwt.dropna(subset=['viewable_for_emp_date_time']) # there is also the id, would be interesting
nrViewableShifts = len(nrViewableShifts.index)
print("Viewable for employee shifts: ", nrViewableShifts)

# how many viewable shifts are realized / not realized (R or NR)
nrViewableShiftsR = dfwt.dropna(subset=['viewable_for_emp_date_time', 'realized_start_date_time']).__len__()
print("Viewable shifts that have been realized: ", nrViewableShiftsR)

nrViewableShiftsNR = dfwt.dropna(subset=['viewable_for_emp_date_time'])
nrViewableShiftsNR = nrViewableShiftsNR.realized_start_date_time.isna().value_counts() # gives False/ True series
print("Viewable shifts that have not been realized: ", nrViewableShiftsNR[nrViewableShiftsNR.index==True].item())

# how many viewable shifts are (not) accepted
dfViewableAcceptedShift = dfwt.dropna(subset=['viewable_for_emp_date_time', 'accept_by_employee_date_time']) # accept has value
nrViewableAcceptedShift = len(dfViewableAcceptedShift.index)
print("Viewable shifts that have been accepted: ", nrViewableAcceptedShift)

dfViewableNAcceptedShift = dfwt.dropna(subset=['viewable_for_emp_date_time'])
nrViewableNAcceptedShift = dfViewableNAcceptedShift.accept_by_employee_date_time.isna().value_counts()
print("Viewable shifts that have not been accepted: ", nrViewableNAcceptedShift[nrViewableNAcceptedShift.index==True].item())

# how many not viewable shifts - called afterwards
# TODO isnull() takes 1 positional argument but 2 were given

# dfNViewable = dfwt.isnull('viewable_for_emp_date_time')
# dfCalledShifts = dfNViewable.dropna(subset=['called_up_date_time'])
# print("Number of not viewable shift that have been called: ", len(dfCalledShifts.index))
# of which have been accepted (you could say success rate)
# sCalledShiftsAceptYN = dfCalledShifts.realized_start_date_time.isna().value_count()
# print(" that resulted in a realised shift  : ", sCalledShiftsAceptYN[sCalledShiftsAceptYN.index==False].item())
# print(" that resulted in a unrealised shift: ", sCalledShiftsAceptYN[sCalledShiftsAceptYN.index==True].item())
# Out:
# Total number of shifts in examined set:  5000
# Viewable for employee shifts:  1300
# Viewable shifts that have been realized:  380
# Viewable shifts that have not been realized:  920
# Viewable shifts that have been accepted:  740
# Viewable shifts that have not been accepted:  560

# %%
nrViewableShiftsNR[nrViewableShiftsNR.index==True].item()
# Out:
# 920

# %% [markdown]
# ## Shifts
# The data gives us all the shifts in a certain period of time including all the attributes. Let's see wat some basic statistics will tell us here.

# %%
dfwt.head(5)
# Out:
#         repository_timestamp op              dms_timestamp         id  \
# 0 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.543285  126361814
# 1 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.724086  125706123
# 2 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.933099  126370048
# 3 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.585765  126362871
# 4 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.883311  126373902
#
#     shift_id     start_date_time       end_date_time realized_start_date_time  \
# 0  131254489 2020-02-12 08:00:00 2020-02-12 17:00:00                      NaT
# 1  131073033 2020-02-13 15:15:00 2020-02-13 18:00:00                      NaT
# 2  131959911 2020-02-14 07:00:00 2020-02-14 15:00:00                      NaT
# 3  131940075 2020-02-10 08:32:00 2020-02-10 15:02:00                      NaT
# 4  131077657 2020-02-10 11:30:00 2020-02-10 14:30:00                      NaT
#
#   realized_end_date_time decl_to_erp_system_date_time  \
# 0                    NaT          2020-02-19 20:25:01
# 1                    NaT                          NaT
# 2                    NaT                          NaT
# 3                    NaT                          NaT
# 4                    NaT                          NaT
#
#   accept_by_employee_date_time  pool_id   deleted_date_time  employee_id  \
# 0          2020-02-06 10:05:14     4550                 NaT       823499
# 1          2020-02-13 14:09:04     5314                 NaT       851774
# 2                          NaT    11462 2020-02-06 09:52:09       861425
# 3                          NaT     8222 2020-02-06 07:24:07       883647
# 4                          NaT     2550 2020-02-06 12:03:16       386860
#
#    pool_employee_id confirmed_date_time viewable_for_emp_date_time  \
# 0           1136288                 NaN                        NaT
# 1           1172843                 NaN                        NaT
# 2           1185349                 NaN                        NaT
# 3           1214419                 NaN                        NaT
# 4            741826                 NaN                        NaT
#
#   called_up_date_time
# 0 2020-02-04 16:44:18
# 1 2020-02-13 10:31:42
# 2                 NaT
# 3 2020-02-04 17:30:07
# 4 2020-02-05 10:16:30

# %% [markdown]
# Already we see that there is sparsity in the data: not all cells have been filled in. Lets see what a basic statistic will indicate:

# %%
# percentile list 
perc =[.20, .40, .60, .80] 

# list of dtypes to include 
include =['int', 'float64', 'datetime64'] 

# calling describe method 
desc = dfwt.describe(percentiles = perc, include = include)

# display
desc
# Out:
#               repository_timestamp               dms_timestamp  \
# count                         5000                        5000
# unique                           1                        5000
# top     2020-08-18 20:22:52.059095  2020-08-18 14:55:40.620006
# freq                          5000                           1
# first   2020-08-18 20:22:52.059095  2020-08-18 14:43:45.531698
# last    2020-08-18 20:22:52.059095  2020-08-18 14:59:00.402786
#
#             start_date_time        end_date_time realized_start_date_time  \
# count                  5000                 5000                     1495
# unique                  532                  595                      425
# top     2020-02-13 07:00:00  2020-02-11 15:00:00      2020-02-13 07:00:00
# freq                    120                   89                       40
# first   2020-02-09 01:30:00  2020-02-09 05:01:00      2020-02-09 05:45:00
# last    2020-02-16 17:00:00  2020-02-16 23:59:00      2020-02-16 16:30:00
#
#        realized_end_date_time decl_to_erp_system_date_time  \
# count                    1490                         1788
# unique                    489                         1412
# top       2020-02-13 15:00:00          2020-02-14 09:11:49
# freq                       22                            7
# first     2020-02-09 13:45:00          2020-02-09 15:00:18
# last      2020-02-16 23:30:00          2020-03-12 00:42:13
#
#        accept_by_employee_date_time    deleted_date_time  \
# count                          2896                 1423
# unique                         2579                 1354
# top             2020-02-06 15:51:06  2020-02-06 10:33:04
# freq                              5                    4
# first           2019-12-15 23:18:56  2019-04-09 15:26:11
# last            2020-02-16 11:51:33  2020-02-19 12:04:07
#
#        viewable_for_emp_date_time  called_up_date_time
# count                        1300                 3835
# unique                        577                 1301
# top           2020-02-06 12:06:07  2020-02-05 15:48:47
# freq                           90                  192
# first         2019-11-26 19:15:08  2019-12-10 13:36:05
# last          2020-02-14 15:15:32  2020-02-16 11:40:50

# %% [markdown]
# ## Custom shift attributes
# This description confirms the sparsity. Of the loaded 5000 columns we found that start and end times have been filled in but the realized times are missing in 5000-1495=3505 shifts, over 2/3rd. Furthermore we count almost 600 unique start and end times.
# Combining/processing columns could give more insight (don't forget there are 84 columns to choose from, they are at the beginning of this notebook). We could apply the following:
#  - bin times based on the *start_date_time*
#  - calculate a planned shift duration (delta between *start_date_time* and *end_date_time*)
#  - calculate a realised shift duration (delta between *start_date_time* and *end_date_time*)
#  - caluclate a deviation in start and end time e.g. delta in start time; end time; duration
#  - more ...?

# %% [markdown]
# let's start with binning the data, here `groupby` is usefull

# %%
# make df that bins the times (panda calls this grouping, hence `groupby` )
# since we group for *start_date_time* we copy this info for later use
dfwt['StartDTCopy']= dfwt['start_date_time']

# do the grouping
# make df that counts per hour

# use generic counter
# for minutes use e.g. freq='15T'
# for hours use e.g. freq='2H'
dfg = dfwt.groupby(pd.Grouper(key='start_date_time', freq='1H')).count()

# alternative code:
# dfg = dfwt.groupby(dfwt['start_date_time'].dt.hour).size()

# %% [markdown]
# Lets inspect the result, in the most left label you see the grouping effect, as expected most shifts start during 0600-0700 (first row is 0000-0100). You can play around with the minute option to have a more detailed overview, this will give also better visualisations)

# %%
dfg.head(10)
# Out:
#                      repository_timestamp  op  dms_timestamp  id  shift_id  \
# start_date_time
# 2020-02-09 01:00:00                     1   1              1   1         1
# 2020-02-09 02:00:00                     0   0              0   0         0
# 2020-02-09 03:00:00                     0   0              0   0         0
# 2020-02-09 06:00:00           14
# 2020-02-09 07:00:00           34
# 2020-02-09 08:00:00            6
# 2020-02-09 09:00:00           11
# 2020-02-09 10:00:00            1

# %% [markdown]
# ### Cumulative shifts per period of time
# lets make a plot using Seaborn, and have the resolution of the groups set to 30 min, you can safely use *repository_timestamp* as a counter (on the y-axis) since it has no Nulls.

# %%
# see if we can make a plot with lines
# note: we use 
dfg2 = dfwt.groupby(pd.Grouper(key='start_date_time', freq='30T')).count()
sns.set_theme(style="darkgrid")
# sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set(rc={'figure.figsize':(20.0,8)})
start_plot = sns.lineplot(x='start_date_time', y='repository_timestamp', data=dfg2)
piet = plt.setp(start_plot.get_xticklabels(), rotation=45)

# %%
# use pandas build in plot
fig, ax = plt.subplots()
# swithc on minor TICKS
ax.minorticks_on()
# Customize the major grid
ax.grid(which='major', linestyle='-', linewidth='0.5', color='grey')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

dfg2.plot(kind='line', y='repository_timestamp', ax=ax)

# %% [markdown]
# As you might have guessed, 10 feb 2020 was a Monday!

# %%
# zoom out to daily basis
dfg2 = dfwt.groupby(pd.Grouper(key='start_date_time', freq='1D')).count()
# use pandas build in plot again
fig, ax = plt.subplots()
# swithc on minor TICKS
ax.minorticks_on()
# Customize the major grid
ax.set_ylim([0,1200])
ax.grid(which='major', linestyle='-', linewidth='0.5', color='grey')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

dfg2.plot(kind='line', y='repository_timestamp', ax=ax)

# %% [markdown]
# ## Adding attributes
# Now we can investigate frequencies of shifts, uncatagorised. Let's add some features of interest

# %%
# shift duration
dfwt['PlannedShiftDuration'] = dfwt['end_date_time'] - dfwt['start_date_time']
dfwt['RealizedShiftDuration'] = dfwt['realized_end_date_time'] - dfwt['realized_start_date_time']
# start end Deltas
dfwt['StartDelta'] = dfwt['start_date_time'] - dfwt['realized_start_date_time']
dfwt['EndDelta'] = dfwt['end_date_time'] - dfwt['realized_end_date_time']

# how much deviates a shift from planning
dfwt['DurationDelta'] = dfwt['PlannedShiftDuration'] - dfwt['RealizedShiftDuration']


# caclulate the delta in minutes, this requires some data knowlegde, 
# since substracting datetime64-type yields a timedelta-type

# %% [markdown]
# ### `datetime` and `timedelta` types
# special note for working with time in pandas. This is a special class, that is needed when constructing as pandas dateframe, because otherwise dates get stored as an object or string, after which they take up too much memory and you can do nothing with them (e.g. substracting). On the other hand, when constructing plots, a timedelta-type causes trouble. The plotting lib wants e.g. `int` or `float`, in order to do so, you can divide the timedelta with a timedelta and yield `floats64` in this case. If you have specified minutes `m` than you get the delta in minutes.
# For the sake of clarity *PlannedShiftDuration* is not devided, and note the type is still `timedelta64` in this case.
#
# NOTE: all differences will be in the following units:
#  * Deltas will be in _minutes_
#  * Durations will be in _hours_
#
#
# subject to change, but for now the idea is that it will make comparisson most easily

# %%
# devide by minutes to get time delta in minutes
dfwt['StartDelta'] = dfwt['StartDelta'] / np.timedelta64(1, 'm')
dfwt['EndDelta']   = dfwt['EndDelta'] / np.timedelta64(1, 'm')
dfwt['RealizedShiftDuration'] = dfwt['RealizedShiftDuration'] / np.timedelta64(1, 'h')
dfwt['DurationDelta'] = dfwt['DurationDelta'] / np.timedelta64(1, 'm')
# inspect the types of the data
dfwt.dtypes
# Out:
# repository_timestamp             datetime64[ns]
# op                                       object
# dms_timestamp                    datetime64[ns]
# id                                        int64
# shift_id                                  int64
# start_date_time                  datetime64[ns]
# end_date_time                    datetime64[ns]
# realized_start_date_time         datetime64[ns]
# realized_end_date_time           datetime64[ns]
# decl_to_erp_system_date_time     datetime64[ns]
# accept_by_employee_date_time     datetime64[ns]
# pool_id                                   int64
# deleted_date_time                datetime64[ns]
# employee_id                               int64
# pool_employee_id                          int64
# confirmed_date_time                      object
# viewable_for_emp_date_time       datetime64[ns]
# called_up_date_time              datetime64[ns]
# StartDTCopy                      datetime64[ns]
# PlannedShiftDuration            timedelta64[ns]
# RealizedShiftDuration                   float64
# StartDelta                              float64
# EndDelta                                float64
# DurationDelta                           float64
# dtype: object

# %%
# correct PlannedShiftDuration 
dfwt['PlannedShiftDuration'] = dfwt['PlannedShiftDuration'] / np.timedelta64(1, 'h')

# %%
# lets inspect some of the data:
dfwt
# Out:
#            repository_timestamp op              dms_timestamp         id  \
# 0    2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.543285  126361814
# 1    2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.724086  125706123
# 2    2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.933099  126370048
# 3    2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.585765  126362871
# 4    2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.883311  126373902
# ...                         ... ..                        ...        ...
# 4995 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:50.027251  126555792
# 4996 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:50.169588  126371808
# 4997 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:49.737229  126352485
# 4998 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:49.843755  125295938
# 4999 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:01.344925  125271234
#
#        shift_id     start_date_time       end_date_time  \
# 0     131254489 2020-02-12 08:00:00 2020-02-12 17:00:00
# 1     131073033 2020-02-13 15:15:00 2020-02-13 18:00:00
# 2     131959911 2020-02-14 07:00:00 2020-02-14 15:00:00
# 3     131940075 2020-02-10 08:32:00 2020-02-10 15:02:00
# 4     131077657 2020-02-10 11:30:00 2020-02-10 14:30:00
# ...         ...                 ...                 ...
# 4995  132037446 2020-02-11 09:30:00 2020-02-11 15:00:00
# 4996  131859142 2020-02-11 20:30:00 2020-02-11 23:30:00
# 4997  131333706 2020-02-11 10:00:00 2020-02-11 18:30:00
# 4998  130742226 2020-02-13 15:00:00 2020-02-14 00:00:00
# 4999  130718913 2020-02-10 14:00:00 2020-02-10 22:30:00
#
#      realized_start_date_time realized_end_date_time  \
# 0                         NaT                    NaT
# 1                         NaT                    NaT
# 2                         NaT                    NaT
# 3                         NaT                    NaT
# 4                         NaT                    NaT
# ...                       ...                    ...
# 4995                      NaT                    NaT
# 4996      2020-02-11 20:30:00    2020-02-11 23:30:00
# 4997      2020-02-11 10:00:00    2020-02-11 18:45:00
# 4998      2020-02-13 15:00:00    2020-02-14 00:00:00
# 4999      2020-02-10 14:00:00    2020-02-10 22:30:00
#
#      decl_to_erp_system_date_time accept_by_employee_date_time  pool_id  \
# 0             2020-02-19 20:25:01          2020-02-06 10:05:14     4550
# 1                             NaT          2020-02-13 14:09:04     5314
# 2                             NaT                          NaT    11462
# 3                             NaT                          NaT     8222
# 4                             NaT                          NaT     2550
# ...                           ...                          ...      ...
# 4995          2020-02-23 22:20:21                          NaT     5719
# 4996          2020-02-12 10:53:02                          NaT      225
# 4997          2020-02-12 08:28:31          2020-02-06 15:31:05    19963
# 4998          2020-02-14 15:58:41          2020-02-04 16:24:08    12222
# 4999          2020-02-12 18:47:25          2020-02-05 17:20:45     3326
#
#        deleted_date_time  employee_id  pool_employee_id confirmed_date_time  \
# 0                    NaT       823499           1136288                 NaN
# 1                    NaT       851774           1172843                 NaN
# 2    2020-02-06 09:52:09       861425           1185349                 NaN
# 3    2020-02-06 07:24:07       883647           1214419                 NaN
# 4    2020-02-06 12:03:16       386860            741826                 NaN
# ...                  ...          ...               ...                 ...
# 4995 2020-02-10 13:49:43       843149           1161935                 NaN
# 4996                 NaT       787661           1090296                 NaN
# 4997                 NaT       710134           1204582                 NaN
# 4998                 NaT       861372           1185279                 NaN
# 4999                 NaT       660501            922763                 NaN
#
#      viewable_for_emp_date_time called_up_date_time         StartDTCopy  \
# 0                           NaT 2020-02-04 16:44:18 2020-02-12 08:00:00
# 1                           NaT 2020-02-13 10:31:42 2020-02-13 15:15:00
# 2                           NaT                 NaT 2020-02-14 07:00:00
# 3                           NaT 2020-02-04 17:30:07 2020-02-10 08:32:00
# 4                           NaT 2020-02-05 10:16:30 2020-02-10 11:30:00
# ...                         ...                 ...                 ...
# 4995                        NaT 2020-02-10 11:01:57 2020-02-11 09:30:00
# 4996                        NaT 2020-02-05 16:30:40 2020-02-11 20:30:00
# 4997                        NaT 2020-02-06 10:48:31 2020-02-11 10:00:00
# 4998        2020-01-06 01:06:35 2020-02-04 16:15:12 2020-02-13 15:00:00
# 4999        2020-01-06 00:48:17 2020-02-05 10:07:53 2020-02-10 14:00:00
#
#       PlannedShiftDuration  RealizedShiftDuration  StartDelta  EndDelta  \
# 0                     9.00                    NaN         NaN       NaN
# 1                     2.75                    NaN         NaN       NaN
# 2                     8.00                    NaN         NaN       NaN
# 3                     6.50                    NaN         NaN       NaN
# 4                     3.00                    NaN         NaN       NaN
# ...                    ...                    ...         ...       ...
# 4995                  5.50                    NaN         NaN       NaN
# 4996                  3.00                   3.00         0.0       0.0
# 4997                  8.50                   8.75         0.0     -15.0
# 4998                  9.00                   9.00         0.0       0.0
# 4999                  8.50                   8.50         0.0       0.0
#
#       DurationDelta
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 4995            NaN
# 4996            0.0
# 4997          -15.0
# 4998            0.0
# 4999            0.0
#
# [5000 rows x 24 columns]

# %%
# plot the distibution for the planned shift duration
fig, ax = plt.subplots()
# swithc on minor TICKS
ax.minorticks_on()
# Customize the major grid
ax.grid(which='major', linestyle='-', linewidth='0.5', color='grey')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

sns.histplot(x='PlannedShiftDuration', data=dfwt, bins=50, kde=True)

# %% [markdown]
# # Stats on extra attributes
# Do again a summary on the statistical properties

# %%
list(dfwt.columns)
# Out:
# ['repository_timestamp',
#  'op',
#  'dms_timestamp',
#  'id',
#  'shift_id',
#  'start_date_time',
#  'end_date_time',
#  'realized_start_date_time',
#  'realized_end_date_time',
#  'decl_to_erp_system_date_time',
#  'accept_by_employee_date_time',
#  'pool_id',
#  'deleted_date_time',
#  'employee_id',
#  'pool_employee_id',
#  'confirmed_date_time',
#  'viewable_for_emp_date_time',
#  'called_up_date_time',
#  'StartDTCopy',
#  'PlannedShiftDuration',
#  'RealizedShiftDuration',
#  'StartDelta',
#  'EndDelta',
#  'DurationDelta']

# %% [markdown]
# ### DurationDelta: over- or underperformance on planning

# %%
# copy the table, and sort
dfpc = dfwt

# drop NaNs
dfpc = dfpc[dfpc['DurationDelta'].notna()]

# pick value between a range
durdeltamin = -200
durdeltamax = 200
dfpc = dfpc[dfpc.DurationDelta.between(durdeltamin, durdeltamax)]

# sort
dfpc.sort_values('DurationDelta')

# plot the distibution for the planned shift duration
fig, ax = plt.subplots()
# swithc on minor TICKS
ax.minorticks_on()
# Customize the major grid
ax.grid(which='major', linestyle='-', linewidth='0.8', color='grey')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

sns.histplot(x='DurationDelta', data=dfpc, bins=50, kde=True)

# %%
# what info has called_up_date_time
dfcal = dfwt

# drop NaNs
dfcal = dfcal[dfcal['called_up_date_time'].notna()]
print("Number of rows containing valid value: ", len(dfcal.index))

# check delta's
dfcal['CallStartDelta'] = dfcal['start_date_time'] - dfcal['called_up_date_time']
dfcal['CallStartDelta'] = dfcal['CallStartDelta'] / np.timedelta64(1, 'D')

# sort
dfcal.sort_values('CallStartDelta')
# plot the distibution for the planned shift duration
fig, ax = plt.subplots()
# swithc on minor TICKS
ax.minorticks_on()
# Customize the major grid
ax.grid(which='major', linestyle='-', linewidth='0.8', color='grey')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

sns.histplot(x='CallStartDelta', data=dfcal, bins=50, kde=True)
# Out:
# Number of rows containing valid value:  3835
# <ipython-input-44-7f0c3f1381e4>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfcal['CallStartDelta'] = dfcal['start_date_time'] - dfcal['called_up_date_time']
# <ipython-input-44-7f0c3f1381e4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfcal['CallStartDelta'] = dfcal['CallStartDelta'] / np.timedelta64(1, 'D')

# %%
# take columns of interset, this omits too much output 
# - that are 6 till 12, names would be less prone to index shifts
# TODO

sum_cols = [
 'StartDTCopy',
 'PlannedShiftDuration',
 'RealizedShiftDuration',
 'StartDelta',
 'EndDelta']

dfsum = dfwt[sum_cols]

# calling describe method 
# desc = dfsum.describe(percentiles = perc, include = include)
desc = dfsum.describe(include = include)

# display
desc
# Out:
#                 StartDTCopy  PlannedShiftDuration  RealizedShiftDuration  \
# count                  5000           5000.000000            1487.000000
# unique                  532                   NaN                    NaN
# top     2020-02-13 07:00:00                   NaN                    NaN
# freq                    120                   NaN                    NaN
# first   2020-02-09 01:30:00                   NaN                    NaN
# last    2020-02-16 17:00:00                   NaN                    NaN
# mean                    NaN              7.502427               7.256108
# std                     NaN              1.913169               2.143505
# min                     NaN              0.016667               1.000000
# 25%                     NaN              6.750000               6.000000
# 50%                     NaN              8.083333               8.000000
# 75%                     NaN              8.750000               8.500000
# max                     NaN             19.500000              24.000000
#
#          StartDelta     EndDelta
# count   1495.000000  1490.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# first           NaN          NaN
# last            NaN          NaN
# mean      -0.443478     0.863758
# std       38.130746    64.942674
# min     -739.000000 -1250.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.000000
# 75%        0.000000     0.000000
# max      450.000000   490.000000

# %% [markdown]
# This summary uses the RealizedShiftDuration of 1487 shifts, of the 5000 PlannedShiftDuration. The missing ones are not filled in. On average a shift is planned for 7.5 hour, on average 7.25 hour is realized, with a sigma of 2.14 hour.
# The StartDelta and EndDelta indicate that on average a shift is stared and ended almost perfect on time. The $\sigma_{StartDelta}=38$ min and $\sigma_{EndDelta}=65$ min.
# It

# %%
# aggregate deltas per pool
# dfdp = dfwt.groupby(by=['start_date_time'])
dfdp = dfwt.groupby(pd.Grouper(key='start_date_time', freq='1D'))
# dfdp = dfdp.groupby('pool_id')
dfdp.head(10)
# Out:
#            repository_timestamp op              dms_timestamp         id  \
# 4170 2020-08-18 20:22:52.059095  I 2020-08-18 14:58:37.767276  125044502
# 1189 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:58.942877  126387667
# 4432 2020-08-18 20:22:52.059095  I 2020-08-18 14:58:30.306552  125044193
# 4593 2020-08-18 20:22:52.059095  I 2020-08-18 14:58:37.117251  125044433
# 526  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:50.166973  126370747
# 1433 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:01.411479  126031600
# 2182 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:16.947184  126398858
# 2362 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:07.973489  126388112
# 3091 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.962888  126379451
# 4503 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:08.397131  126377996
# 3622 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.559149  126361713
# 4554 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:13.169030  126389871
# 200  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.820398  126383189
# 1666 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:10.358920  126407239
# 3963 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.330675  126377684
# 754  2020-08-18 20:22:52.059095  I 2020-08-18 14:58:01.825157  126212927
# 2269 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:05.618337  126377646
# 820  2020-08-18 20:22:52.059095  I 2020-08-18 14:57:59.935280  121456884
# 1949 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:10.405778  126408283
# 2065 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:13.187407  126400000
# 251  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.015914  126363643
# 1974 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:58.977495  125322538
# 3383 2020-08-18 20:22:52.059095  I 2020-08-18 14:57:01.987434  123534663
# 3595 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.877862  126369923
# 3869 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.640322  126363484
# 4292 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:47.927861  126369891
# 4570 2020-08-18 20:22:52.059095  I 2020-08-18 14:57:02.615307  123534819
# 68   2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.157361  125706414
# 1179 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.922744  125706367
# 3229 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.725985  125706241
# 3493 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.849130  126363343
# 9    2020-08-18 20:22:52.059095  I 2020-08-18 14:43:48.019093  126363649
# 1080 2020-08-18 20:22:52.059095  I 2020-08-18 14:57:49.715714  123534479
# 4354 2020-08-18 20:22:52.059095  I 2020-08-18 14:57:02.871342  123534854
# 2001 2020-08-18 20:22:52.059095  I 2020-08-18 14:58:20.093009  124613051
# 2020 2020-08-18 20:22:52.059095  I 2020-08-18 14:57:05.072690  124489872
# 515  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.203118  125706481
# 2592 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.200676  125706525
# 2848 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.922902  125706506
# 1257 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:58.927509  126376814
# 1871 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:07.951801  126399265
# 655  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.842235  126363274
# 4347 2020-08-18 20:22:52.059095  I 2020-08-18 14:57:03.256755  123534768
# 56   2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.726078  125706255
# 2650 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.203241  125706507
# 3835 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.149694  125706448
# 578  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:58.978425  126377608
# 1556 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:08.140428  126376962
# 10   2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.820461  126383192
# 907  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:58.906440  126383182
# 753  2020-08-18 20:22:52.059095  I 2020-08-18 14:43:45.642805  126363500
# 4846 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:01.374022  126384907
# 1639 2020-08-18 20:22:52.059095  I 2020-08-18 14:44:10.385600  126401287
# 1061 2020-08-18 20:22:52.059095  I 2020-08-18 14:43:46.849222  126363345
# 836  2020-08-18 20:22:52.059095  I 2020-08-18 14:57:52.209442  123534990
# 1920 2020-08-18 20:22:52.059095  I 2020-08-18 14:57
# 3980 2020-02-04 16:47:28 2020-02-16 06:00:00              8.000000
# 4633 2020-02-06 11:42:29 2020-02-16 06:00:00              8.000000
# 4929 2020-02-06 11:58:26 2020-02-16 06:00:00              8.000000
# 465  2020-02-10 14:36:39 2020-02-16 06:30:00             10.500000
# 1897 2020-02-05 16:26:17 2020-02-16 06:30:00              8.000000
#
#       RealizedShiftDuration  StartDelta  EndDelta  DurationDelta
# 4170                    NaN         NaN       NaN            NaN
# 1189                    NaN         NaN       NaN            NaN
# 4432                    NaN         NaN       NaN            NaN
# 4593                    NaN         NaN       NaN            NaN
# 526                8.000000         0.0       0.0            0.0
# 1433                    NaN         NaN       NaN            NaN
# 2182               8.000000         0.0       0.0            0.0
# 2362                    NaN         NaN       NaN            NaN
# 3091                    NaN         NaN       NaN            NaN
# 4503                    NaN         NaN       NaN            NaN
# 3622                    NaN         NaN       NaN            NaN
# 4554                    NaN         NaN       NaN            NaN
# 200                     NaN         NaN       NaN            NaN
# 1666               6.683333         0.0      49.0           49.0
# 3963                    NaN         NaN       NaN            NaN
# 754                     NaN         NaN       NaN            NaN
# 2269                    NaN         NaN       NaN            NaN
# 820                     NaN         NaN       NaN            NaN
# 1949                    NaN         NaN       NaN            NaN
# 2065                    NaN         NaN       NaN            NaN
# 251                5.916667         3.0      23.0           20.0
# 1974                    NaN         NaN       NaN            NaN
# 3383                    NaN         NaN       NaN            NaN
# 3595               5.950000         3.0      21.0           18.0
# 3869               5.733333        -8.0      23.0           31.0
# 4292                    NaN         NaN       NaN            NaN
# 4570                    NaN         NaN       NaN            NaN
# 68                      NaN         NaN       NaN            NaN
# 1179               5.283333        20.0     -12.0          -32.0
# 3229                    NaN         NaN       NaN            NaN
# 3493                    NaN         NaN       NaN            NaN
# 9                  6.083333         0.0      10.0           10.0
# 1080               6.116667         7.0      15.0            8.0
# 4354               3.433333        23.0     192.0          169.0
# 2001                    NaN         NaN       NaN            NaN
# 2020                    NaN         NaN       NaN            NaN
# 515                     NaN         NaN       NaN            NaN
# 2592                    NaN        37.0       NaN            NaN
# 2848                    NaN         NaN       NaN            NaN
# 1257                    NaN         NaN       NaN            NaN
# 1871                    NaN         NaN       NaN            NaN
# 655                     NaN         NaN       NaN            NaN
# 4347                    NaN         NaN       NaN            NaN
# 56                      NaN         NaN       NaN            NaN
# 2650                    NaN         NaN       NaN            NaN
# 3835                    NaN         NaN       NaN            NaN
# 578                     NaN         NaN       NaN            NaN
# 1556                    NaN         NaN       NaN            NaN
# 10                      NaN         NaN       NaN            NaN
# 907                     NaN         NaN       NaN            NaN
# 753                6.033333         2.0      15.0           13.0
# 4846              10.116667        34.0      27.0           -7.0
# 1639                    NaN         NaN       NaN            NaN
# 1061                    NaN         NaN       NaN            NaN
# 836                     NaN         NaN       NaN            NaN
# 1920                    NaN         NaN       NaN            NaN
# 4286                    NaN         NaN       NaN            NaN
# 4362                    NaN         NaN       NaN            NaN
# 4957                    NaN         NaN       NaN            NaN
# 73                      NaN         NaN       NaN            NaN
# 1526               3.000000         0.0       0.0            0.0
# 4477                    NaN         NaN       NaN            NaN
# 235                     NaN         NaN       NaN            NaN
# 1829                    NaN         NaN       NaN            NaN
# 1163                    NaN         NaN       NaN            NaN
# 1912                    NaN         NaN       NaN            NaN
# 2099                    NaN         NaN       NaN            NaN
# 3391                    NaN         NaN       NaN            NaN
# 283                     NaN         NaN       NaN            NaN
# 517                     NaN         NaN       NaN            NaN
# 173                8.000000         0.0       0.0            0.0
# 560                8.000000         0.0       0.0            0.0
# 1929                    NaN         NaN       NaN            NaN
# 2155               4.000000         0.0     240.0          240.0
# 3013                    NaN         NaN       NaN            NaN
# 3980                    NaN         NaN       NaN            NaN
# 4633                    NaN         NaN       NaN            NaN
# 4929                    NaN         NaN       NaN            NaN
# 465               10.000000         0.0      30.0           30.0
# 1897               8.000000         0.0       0.0            0.0

# %% [markdown]
# # Make it BIG
# Let's take all this weeks data into account
#
# _NOTE: THE FOLLOWING CELLs TAKE MINUTES PER CELL_

# %%
timea = time.time()
dfb = pd.read_csv(data_folder / "repo_iplan_employee_in_shift_20200210-20200216.csv", 
                       names=column_names, usecols=cols_of_interest, parse_dates=["repository_timestamp",
                "dms_timestamp",
                "start_date_time",
                "end_date_time",
                "realized_start_date_time",
                "realized_end_date_time",
                "decl_to_erp_system_date_time",
                "accept_by_employee_date_time",
                "viewable_for_emp_date_time",
                "deleted_date_time",
                "called_up_date_time"], skip_blank_lines=False)
timeb = time.time()
print("number of columns : ", len(dfb.columns))
print("number of rows    : ", len(dfb.index))
print("runntime          : ", timeb - timea)
# meanwhile limit the setsize, just in case
if set_size > len(dfb.index): 
    set_size = len(dfb.index)
# Out:
# number of columns :  18
# number of rows    :  248119
# runntime          :  3.2810397148132324

# %%
# high level stats on this data
ns = len(dfb.index)
print("Total number of shifts   : ", ns, "\n")
# number of pools
timea = time.time()
dfbpools = dfb.groupby(['pool_id']).nunique()
print("Number of unique pools   : ", len(dfbpools.index))
del dfbpools

dfbshifts = dfb.groupby(['shift_id']).nunique()
print("Number of unique shifts  : ", len(dfbshifts.index))
del dfbshifts

# number of deleted shifts
dfbshifts = dfb.dropna(subset=['deleted_date_time'])
print("Number of deleted shifts : ", len(dfb.index) - len(dfbshifts))

del dfbshifts

# number of (un)realized shifts
dfbrelshift = dfb.dropna(subset=['realized_start_date_time'])
print("Nr. of realized shifts   : ", len(dfbrelshift.index))
nunrel = len(dfb.index) - len(dfbrelshift.index)
print("Nr. of unrealized shifts : ", nunrel)
del dfbrelshift

# number of called up shifts
dfcalled = dfb.dropna(subset=['called_up_date_time'])
print("Nr. of called up shifts  : ", len(dfcalled.index))
del dfcalled

timeb = time.time()
dt =  timeb - timea
print("runtime: ", round(dt, 2))
# Out:
# Total number of shifts   :  248119
#
# Number of unique pools   :  472
# Number of unique shifts  :  72017
# Number of deleted shifts :  167967
# Nr. of realized shifts   :  61219
# Nr. of unrealized shifts :  186900
# Nr. of called up shifts  :  168750
# runtime:  3.26

# %%
167967 + 61219 + 186900
# Out:
# 416086
